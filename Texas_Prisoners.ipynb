# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
# %matplotlib inline

# %%
# !wget http://www.tdcj.state.tx.us/documents/High_Value_Data_Sets.xlsx
# Out:
# --2021-05-08 01:03:21--  http://www.tdcj.state.tx.us/documents/High_Value_Data_Sets.xlsx
# Resolving www.tdcj.state.tx.us (www.tdcj.state.tx.us)... 168.58.228.12
# Connecting to www.tdcj.state.tx.us (www.tdcj.state.tx.us)|168.58.228.12|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.tdcj.texas.gov/documents/High_Value_Data_Sets.xlsx [following]
# --2021-05-08 01:03:21--  https://www.tdcj.texas.gov/documents/High_Value_Data_Sets.xlsx
# Resolving www.tdcj.texas.gov (www.tdcj.texas.gov)... 168.58.228.12
# Connecting to www.tdcj.texas.gov (www.tdcj.texas.gov)|168.58.228.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17789219 (17M) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘High_Value_Data_Sets.xlsx.1’
#
# 100%[======================================>] 17,789,219  6.11MB/s   in 2.8s
#
# 2021-05-08 01:03:24 (6.11 MB/s) - ‘High_Value_Data_Sets.xlsx.1’ saved [17789219/17789219]

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 19.8 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.7

# %%
df_Texas_Prisoners = pd.read_excel('./High_Value_Data_Sets.xlsx')

# %%
a = df_Texas_Prisoners

# %%
a.T.index
# Out:
# Index(['SID Number', 'TDCJ Number', 'Name', 'Current Facility', 'Gender',
#        'Race', 'Age', 'Projected Release', 'Maximum Sentence Date',
#        'Parole Eligibility Date', 'Case Number', 'County', 'Offense Code',
#        'TDCJ Offense', 'Sentence Date', 'Offense Date', 'Sentence (Years)',
#        'Last Parole Decision', 'Next Parole Review Date',
#        'Parole Review Status'],
#       dtype='object')

# %%
a.head()
# Out:
#    SID Number  TDCJ Number                  Name Current Facility Gender Race  \
# 0      524524       758486  HARPER,DAVID JOHN JR          Estelle      M    W
# 1      703267       841623    RODRIGUEZ,THEODORE             Beto      M    W
# 2      766785       365547    BROWN,NARRIES EARL        Jester IV      M    W
# 3      770626       449674         FLORES,ISABEL             Pack      M    H
# 4      771601      1491019     MOLETT,JOHN HENRY             Pack      M    B
#
#    Age    Projected Release Maximum Sentence Date Parole Eligibility Date  \
# 0   92  9999-01-01 00:00:00   9999-01-01 00:00:00     2026-08-03 00:00:00
# 1   83  2043-08-03 00:00:00   2043-08-03 00:00:00     2021-02-01 00:00:00
# 2   84  9999-01-01 00:00:00   9999-01-01 00:00:00     2003-08-24 00:00:00
# 3   84  9999-01-01 00:00:00   9999-01-01 00:00:00     2006-09-02 00:00:00
# 4   78  2037-12-02 00:00:00   2037-12-02 00:00:00     2022-12-02 00:00:00
#
#     Case Number    County  Offense Code             TDCJ Offense  \
# 0      95-765-C  McLennan      11180000       AGG SEXUAL ASSAULT
# 1      97-396-C  McLennan      11990003             AGG SEX ASLT
# 2  F83-89728-HI    Dallas      11220000  AGG SEX ABUSE CHILD/U14
# 3   86CR-1234-B    Nueces       9150000      MURDER W/DEADLY WPN
# 4       1144294    Harris      12990002         AGG ROBBERY W/DW
#
#   Sentence Date Offense Date Sentence (Years)  Last Parole Decision  \
# 0    1996-08-13   1995-09-15             Life                  None
# 1    1998-08-05   1996-06-01             45.0                  None
# 2    1983-08-24   1983-03-15             Life  Denied on 12/05/2016
# 3    1987-04-13   1986-09-02             Life  Denied on 07/23/2018
# 4    2008-02-21   2007-12-03             30.0                  None
#
#     Next Parole Review Date      Parole Review Status
# 0                08/03/2026     NOT IN REVIEW PROCESS
# 1  Unavailable at this time  IN PAROLE REVIEW PROCESS
# 2  Unavailable at this time     NOT IN REVIEW PROCESS
# 3                   07/2021  IN PAROLE REVIEW PROCESS
# 4                12/02/2022     NOT IN REVIEW PROCESS

# %%
a.sort_values(by=['Offense Date'])[-5:]
# Out:
#         SID Number  TDCJ Number                  Name Current Facility Gender  \
# 113032    50529573      2340432          URBINA,OSCAR     Glossbrenner      M
# 115560    50696699      2335733  MARTIN,BRANDON JAMES     Glossbrenner      M
# 116423    50753624      2335746  BROOKS,CHRIS DEWAYNE     Glossbrenner      M
# 116780    50777711      2340212       MAZARELLO,RAZEL            Crain      F
# 117253    50809254      2330749       CARABALLO,HENRY     Glossbrenner      M
#
#        Race  Age    Projected Release Maximum Sentence Date  \
# 113032    H   23  2021-09-30 00:00:00   2025-03-05 00:00:00
# 115560    W   25  2021-08-09 00:00:00   2025-01-09 00:00:00
# 116423    B   20  2021-08-09 00:00:00   2031-01-08 00:00:00
# 116780    H   22  2021-12-30 00:00:00   2025-08-21 00:00:00
# 117253    H   21  2021-06-15 00:00:00   2025-09-10 00:00:00
#
#        Parole Eligibility Date Case Number   County  Offense Code  \
# 113032                     NaN         NaN  Hidalgo      29990043
# 115560                     NaN         NaN     Hood      35990014
# 116423                     NaN         NaN    Lamar      35990002
# 116780                     NaN         NaN   Dallas      35990014
# 117253                     NaN         NaN   Harris      22990003
#
#                             TDCJ Offense Sentence Date Offense Date  \
# 113032       AGG ASSAULT W/DEADLY WEAPON           NaT          NaT
# 115560                  POSS CS PG 1 <1G           NaT          NaT
# 116423           MAN DEL CS PG 1 >=1G<4G           NaT          NaT
# 116780                  POSS CS PG 1 <1G           NaT          NaT
# 117253  BURGLARY HABITATION INTEND OTHER           NaT          NaT
#
#        Sentence (Years) Last Parole Decision Next Parole Review Date  \
# 113032              5.0                  NaN                     NaN
# 115560              4.0                  NaN                     NaN
# 116423             10.0                  NaN                     NaN
# 116780              3.0                  NaN                     NaN
# 117253              5.0                  NaN                     NaN
#
#        Parole Review Status
# 113032                  NaN
# 115560                  NaN
# 116423                  NaN
# 116780                  NaN
# 117253                  NaN

# %%
a.iloc[a.index[0]]['Offense Date']
# Out:
# Timestamp('1995-09-15 00:00:00')

# %%
for x in a['Sentence Date']:
    if type(x) == str:
        print(x)

# %%
a[a['Offense Date'] == '#NULL!']
# Out:
# Empty DataFrame
# Columns: [SID Number, TDCJ Number, Name, Current Facility, Gender, Race, Age, Projected Release, Maximum Sentence Date, Parole Eligibility Date, Case Number, County, Offense Code, TDCJ Offense, Sentence Date, Offense Date, Sentence (Years), Last Parole Decision, Next Parole Review Date, Parole Review Status]
# Index: []

# %%
b = a[a['TDCJ Offense'].str.contains('MARIHUANA')]

# %%
b['County'].value_counts()
# Out:
# Cameron          13
# Kleberg           9
# Starr             8
# Carson            6
# McLennan          6
# Tarrant           5
# Webb              4
# Hidalgo           4
# Williamson        3
# Maverick          3
# Brown             2
# Victoria          2
# Comal             2
# Wilbarger         2
# Nacogdoches       2
# Taylor            2
# Harris            2
# Lubbock           1
# Eastland          1
# Haskell           1
# Runnels           1
# Brazos            1
# Hall              1
# Oldham            1
# Fayette           1
# Kenedy            1
# Jim Wells         1
# Sherman           1
# Colorado          1
# Ellis             1
# Kerr              1
# Willacy           1
# Young             1
# Childress         1
# Hays              1
# Chambers          1
# Parker            1
# Titus             1
# Lasalle           1
# Gillespie         1
# Duval             1
# Denton            1
# Orange            1
# Collingsworth     1
# Dewitt            1
# Jackson           1
# Name: County, dtype: int64

# %%
b[b['County'] == 'Cameron']['Current Facility'].value_counts()
# Out:
# Clements         2
# Fort Stockton    1
# Beto             1
# Coffield         1
# Allred           1
# Hutchins         1
# Plane            1
# Torres           1
# Eastham          1
# Jester IV        1
# Ferguson         1
# Dominguez        1
# Name: Current Facility, dtype: int64

# %%
a[a['Current Facility'] == 'Dominguez']['TDCJ Offense'].value_counts()
# Out:
# BURG HABIT                    88
# AGG ROBBERY                   73
# ROBBERY                       62
# AGG ASLT W/DWPN               55
# DWI                           51
#                               ..
# POSS CONT SUB METH             1
# POSS MARIJ 5-50LBS             1
# AGG ASLT FAM MEM SBI W/WPN     1
# MAN DEL CONT SUB DFZ           1
# ATT TAKE WEAPON FROM PO        1
# Name: TDCJ Offense, Length: 672, dtype: int64

# %%
a['TDCJ Number'].value_counts()
# Out:
# 1572864    1
# 548702     1
# 1861465    1
# 1574741    1
# 2101076    1
#           ..
# 2287734    1
# 2289781    1
# 1806040    1
# 2281585    1
# 1837055    1
# Name: TDCJ Number, Length: 117486, dtype: int64

# %%
a[a['Current Facility'] == 'Dominguez']
# Out:
#         SID Number  TDCJ Number                         Name Current Facility  \
# 1850       1970540      2239188               LANE,BOBBY JOE        Dominguez
# 1917       1991673      2265754          COYASO,JOHNNY ANGLE        Dominguez
# 2022       2018661      2213737             MCGRAW,DAVID LEE        Dominguez
# 2247       2071579      2318280        ANDERWALD,BARRY WAYNE        Dominguez
# 2404       2109057      2320742               RAMIREZ,ROLAND        Dominguez
# ...            ...          ...                          ...              ...
# 117274    50810813      2305624          DONAVON,MACK ARTHUR        Dominguez
# 117360    50816617      2337644         RODRIGUEZ,HECTOR III        Dominguez
# 117425    50821019      2316615    SOLIS,JOSE MANUEL SALAZAR        Dominguez
# 117433    50821401      2314696   KELLER,CHRISTOPHER MICHAEL        Dominguez
# 117462    50823454      2335268  AGUIRRE,CHRISTOPHER ALFONSO        Dominguez
#
#        Gender Race  Age    Projected Release Maximum Sentence Date  \
# 1850        M    W   64  2033-09-12 00:00:00   2033-09-12 00:00:00
# 1917        M    H   65  2023-05-12 00:00:00   2027-03-23 00:00:00
# 2022        M    W   63  2021-04-16 00:00:00   2025-05-20 00:00:00
# 2247        M    W   63  2024-03-26 00:00:00   2030-02-12 00:00:00
# 2404        M    H   64  2022-10-17 00:00:00   2022-10-17 00:00:00
# ...       ...  ...  ...                  ...                   ...
# 117274      M    B   23  2023-07-02 00:00:00   2023-07-02 00:00:00
# 117360      M    H   25  2022-02-24 00:00:00   2023-10-07 00:00:00
# 117425      M    H   23  2033-10-15 00:00:00   2033-10-15 00:00:00
# 117433      M    B   25  2022-05-21 00:00:00   2025-11-07 00:00:00
# 117462      M    H   21  2027-10-07 00:00:00   2027-11-01 00:00:00
#
#        Parole Eligibility Date   Case Number     County  Offense Code  \
# 1850       2023-09-13 00:00:00          3169    Coleman      35990002
# 1917       2020-08-04 00:00:00   2019CR5452W      Bexar      35990003
# 2022       2019-03-10 00:00:00        070032    Grayson      22990001
# 2247       2021-03-26 00:00:00      CR19-161    Bandera      48010020
# 2404       2020-02-21 00:00:00   2019CR13045      Bexar      13990075
# ...                        ...           ...        ...           ...
# 117274     2021-07-01 00:00:00  158990001010     Harris      13150005
# 117360     2021-02-10 00:00:00  CR-0668-16-A    Hidalgo      35620012
# 117425     2020-07-09 00:00:00  CR-4766-18-G    Hidalgo      12990001
# 117433     2020-07-17 00:00:00      16-24356  Jefferson      22990002
# 117462     2024-04-07 00:00:00  2020CR11149W      Bexar      13990076
#
#                         TDCJ Offense Sentence Date Offense Date  \
# 1850            MAN DEL CONT SUB DFZ    2018-12-27   2018-06-15
# 1917    POSS W/I DEL CONT SUB 4-200G    2019-05-17   2019-03-23
# 2022                BURG OF BLDG-ENH    2019-02-14   2018-05-12
# 2247            EVADING ARREST W/VEH    2020-05-18   2019-06-25
# 2404                     ASLT FAMILY    2020-06-15   2019-10-18
# ...                              ...           ...          ...
# 117274                   AGG ASLT DW    2020-02-03   2018-05-05
# 117360       POSS MARIJ 50-2,000 LBS    2021-02-10   2016-01-03
# 117425                       ROBBERY    2020-05-19   2018-09-25
# 117433                    BURG HABIT    2020-04-22   2016-01-15
# 117462   ASLT FAMILY CHOKING/STRANGU    2021-01-13   2020-10-31
#
#        Sentence (Years)  Last Parole Decision   Next Parole Review Date  \
# 1850               15.0                  None                09/13/2023
# 1917                8.0  Denied on 02/20/2020  Unavailable at this time
# 2022                7.0  Denied on 03/11/2021                   03/2022
# 2247               10.0  Denied on 03/16/2021                   03/2022
# 2404                3.0  Denied on 03/31/2021                   03/2022
# ...                 ...                   ...                       ...
# 117274              4.0                  None                07/01/2021
# 117360              3.0  Denied on 03/22/2021                02/24/2022
# 117425             15.0  Denied on 09/10/2020                   09/2022
# 117433              6.0  Denied on 06/25/2020                   06/2021
# 117462              7.0                  None                04/07/2024
#
#             Parole Review Status
# 1850       NOT IN REVIEW PROCESS
# 1917    IN PAROLE REVIEW PROCESS
# 2022       NOT IN REVIEW PROCESS
# 2247       NOT IN REVIEW PROCESS
# 2404       NOT IN REVIEW PROCESS
# ...                          ...
# 117274  IN PAROLE REVIEW PROCESS
# 117360     NOT IN REVIEW PROCESS
# 117425     NOT IN REVIEW PROCESS
# 117433  IN PAROLE REVIEW PROCESS
# 117462     NOT IN REVIEW PROCESS
#
# [1742 rows x 20 columns]

# %%
a[a['Name'].str.contains('ROBLES,AD')]
# Out:
#        SID Number  TDCJ Number           Name Current Facility Gender Race  \
# 45099     5937854      2292349  ROBLES,ADRIAN          Briscoe      M    H
#
#        Age    Projected Release Maximum Sentence Date Parole Eligibility Date  \
# 45099   35  2024-08-15 00:00:00   2024-08-15 00:00:00     2022-02-15 00:00:00
#
#       Case Number County  Offense Code              TDCJ Offense  \
# 45099  2019CR7438  Bexar      13150005  AGG ASLT W/DWPN-REPEATER
#
#       Sentence Date Offense Date Sentence (Years) Last Parole Decision  \
# 45099    2019-11-07   2019-04-05              5.0                 None
#
#       Next Parole Review Date   Parole Review Status
# 45099              02/15/2022  NOT IN REVIEW PROCESS
